# %% [markdown]
# ![code.png](attachment:c81254d2-2a8f-45b8-9d20-42b3f8e9b6f1.png)

# %% [markdown]
# # Techniques for Cleaning Data and making data more consistent
# #### by Joe Eberle started on 08/15/2023

# %%
# Install any Libraries your dont already have 
first_install = False 
if first_install:
    # !pip install ydata-profiling
    # !pip install pyttsx3

# %%
# Import all of the libraries you need  !pip install pandas_profiling
import pandas as pd #Pandas is high performance data manipulation 
import os

# %% [markdown]
# ## Optional Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
import configparser 
config = configparser.ConfigParser()
cfg = config.read('config.ini')  

solution_name = 'kids_abc_book'

# %% [markdown]
# ## Optional Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_start(solution_name, start_time) 
ql.set_speaking_log(False)
ql.set_speaking_steps(True)
ql.pvlog('info',f'Process {solution_name} Step 0 - Initializing and starting Process.')
# Out:
# Process kids_abc_book Step 0 - Initializing and starting Process.

# %% [markdown]
# ## Optional Step - Removing Duplicates

# %%
Introduction =  ''' 
Cleansing data is crucial in data science because it ensures the accuracy and reliability of the information used for analysis.
Removing inconsistencies, errors, and outliers from datasets enhances the quality of insights and prevents misleading conclusions. 
CLeaning data eliminates waste and improves processing. 
Simply cleaning data can save a corporation millions of dollars.
'''
talking_introduction  = True
if talking_introduction:
    ql.talk(Introduction)
else:
    print(Introduction)

# %% [markdown]
# ## Optional Step 0 - Build a working directory to house your analysis

# %%
talking_point =  ''' 
removing duplicate rows is often a valuable process and is often done first. 
By removing duplicate rows you can reduce the amount of cleansing as well as make statistics more accurate. 
However, In some data sets having duplicate rows is acceptable. 
'''
speak_talking_point  = True
if speak_talking_point:
    ql.talk(talking_point)
else:
    print(talking_point)

# %%
# Optional Step 0 - Build a working directory to house your analysis
directory_path = r'c:\\working_directory\\ABC_images\\'
# Create the directory if it doesn't exist
if not os.path.exists(directory_path):
    os.makedirs(directory_path)
    print(f"Directory '{directory_path}' created successfully.")
else:
    print(f"Directory '{directory_path}' already exists.")
# Out:
# Directory 'c:\\working_directory\\ABC_images\\' created successfully.

# %%
import os
import random
import matplotlib.pyplot as plt
from IPython.display import Image

def childrens_generative_ABC_book(letter):
    # Specify the directory containing the images
    image_directory = "c:\\working_directory\\ABC_images\\"

    # Get a list of image filenames that start with the given letter
    matching_files = [filename for filename in os.listdir(image_directory) if filename.startswith(letter)]

    if not matching_files:
        print(f"No images found starting with letter '{letter}'.")
    else:
        # Select a random image filename
        selected_filename = random.choice(matching_files)
        image_path = os.path.join(image_directory, selected_filename)

        # Display the image
        img = Image(filename=image_path)
        display(img)

# Example usage:
# To display an image starting with the letter 'A'
childrens_generative_ABC_book('u')

# %% [markdown]
# ## Step 0 - Process End - display log

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))
# Out:
# 2023-09-22 15:26:06,792 - INFO - START data_cleansing =============================================
# 2023-09-22 15:26:06,792 - INFO - START data_cleansing Start Time = 2023-09-22 15:26:06
# 2023-09-22 15:26:06,792 - INFO - data_cleansing Step 0 - Initialize the configuration file parser
# 2023-09-22 15:26:06,814 - INFO - Imported existing <module 'comtypes.gen' from 'C:\\Users\\josep\\anaconda3\\lib\\site-packages\\comtypes\\gen\\__init__.py'>
# 2023-09-22 15:26:06,814 - INFO - Using writeable comtypes cache directory: 'C:\Users\josep\anaconda3\lib\site-packages\comtypes\gen'
# 2023-09-22 15:26:12,298 - INFO - Process data_cleansing Step 0 - Initializing and starting Process.
# 2023-09-22 15:26:44,994 - INFO - data_cleansing - Step 1 - Load ANY data set for which to run discovery or data profiling
# 2023-09-22 15:26:45,389 - INFO - PERFORMANCE data_cleansing The total process duration was:38.60
# ...

# %% [markdown]
# # https://github.com/JoeEberle/
# # josepheberle@outlook.com

# %% [markdown]
# ![developer.png](attachment:developer.png)
